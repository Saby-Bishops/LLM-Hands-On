# %% [markdown]
# <a href="https://colab.research.google.com/github/Saby-Bishops/LLM-Hands-On/blob/main/Inclassexercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install transformers

# %%
from transformers import pipeline

# Load the summarization pipeline
summarizer = pipeline("summarization")

# Input text
text = """Large language models are transforming natural language processing by providing frameworks that can understand and generate human-like text based on the input they receive. These models have been trained on vast amounts of text data, allowing them to capture complex patterns in language and improve various applications like translation, summarization, and question answering."""

# Generate summary
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)

# Print the summarized text
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' Large language models are transforming natural language processing by providing frameworks that can understand and generate human-like text . These models have been trained on vast amounts of text data, allowing them to capture complex patterns in language .'}]

# %%
from transformers import pipeline

# Load the summarization pipeline
summarizer = pipeline("summarization")

# Input text
text = """I am Saniya Pandita and have completed 12th grade of senior school with 93 % above and have gained admission into Integrated M.Tech dual program in computer science with specialization in Data science thru merit in VIT(NIRF Rank=12) in India and currently in 1st Semester. I have strong passion towards computer coding and was clearly aligned towards same since my childhood days due to which I was selected to Japan Robotics program in Japan from my school Bishop Cotton Girls School . I would love to be part of this and complete same with great enthusiasm and apply same wherever I take up to work and this course will help me to gain knowledge while studying."""

# Generate summary
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)

# Print the summarized text
print(summary)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'summary_text': ' Saniya Pandita has strong passion towards computer coding . She was selected to Japan Robotics program in Japan . She would love to be part of this and complete same with great enthusiasm .'}]

# %%
from google.colab import files
from transformers import pipeline

# Initialize the summarization pipeline
summarizer = pipeline("summarization")

# Upload files
uploaded = files.upload()  # This will prompt for file upload

# Process each uploaded file
for filename in uploaded.keys():
    print(f"Processing file: {filename}")
    with open(filename, 'r') as file:
        text = file.read()

    # Generate summary for the content of the file
    summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
    print(f"Summary: {summary}")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
#      <input type="file" id="files-0591bd0b-8a9b-455e-9b0a-6d888872527a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0591bd0b-8a9b-455e-9b0a-6d888872527a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...

# %%
from transformers import pipeline

# Initialize the sentiment analysis pipeline
classifier = pipeline("sentiment-analysis")

# Example text
result = classifier("I love learning about AI!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.99968421459198}]

# %%
from transformers import pipeline

# Initialize the sentiment analysis pipeline
classifier = pipeline("sentiment-analysis")

# Example text
result = classifier("I hate extreme cold temperatures!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'NEGATIVE', 'score': 0.9354109168052673}]
